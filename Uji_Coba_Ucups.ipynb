# %% [markdown]
# <a href="https://colab.research.google.com/github/ikanx101/G-Colab/blob/main/Uji_Coba_Ucups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rm(list=ls())
library(readxl)
library(dplyr)

data = read_excel("Dummies.xlsx",skip = 1)
data = janitor::clean_names(data)
colnames(data)[1:4] = c("id","nama","nickname","no_hp")
colnames(data)[9] = "kota_riset"
colnames(data)[13] = "kota_kab_domisili"
colnames(data)[14:22] = c("gender","dd","mm","yyyy","ses","pekerjaan","nama_sekolah",
                          "akun_ig","akun_fb")
str(data)
# Out:
# New names:
# * `` -> ...1
# * `` -> ...2
# * `` -> ...3
# * `` -> ...4
# * `Kota/Kabupaten` -> `Kota/Kabupaten...9`
# * ...
# tibble [722 × 22] (S3: tbl_df/tbl/data.frame)
#  $ id               : chr [1:722] "2018-08-01-001" "2018-08-01-002" "2018-08-01-003" "2018-08-01-004" ...
#  $ nama             : chr [1:722] "Gandhi" "Abdul Hafidz" "Abimanyu" "Abudzar FM" ...
#  $ nickname         : chr [1:722] "Ucup" "Ucup" "Ucup" "Ucup" ...
#  $ no_hp            : chr [1:722] "081295981629" "083872314119" "085846001404" "085215311300" ...
#  $ sumber_responden : chr [1:722] "Turun Lapangan" "Turun Lapangan" "Turun Lapangan" "Turun Lapangan" ...
#  $ id_rekomendator  : chr [1:722] NA NA NA NA ...
#  $ jenis_project    : chr [1:722] "Annual Research" "Annual Research" "Annual Research" "Annual Research" ...
#  $ sub_brand        : chr [1:722] "HiLo Teen" "HiLo Teen" "HiLo Teen" "HiLo Teen" ...
#  $ kota_riset       : chr [1:722] "Jakarta" "Jakarta" "Jakarta" "Jakarta" ...
# ...

# %%
data
# Out:
#     id             nama                     nickname
# 1   2018-08-01-001 Gandhi                   Ucup
# 2   2018-08-01-002 Abdul Hafidz             Ucup
# 3   2018-08-01-003 Abimanyu                 Ucup
# 4   2018-08-01-004 Abudzar FM               Ucup
# 5   2018-08-01-005 Achmad Ilham A           Ucup
# 6   2018-08-01-006 Adelia Anggraeni         Ucup
# 7   2018-08-01-007 Adwa                     Ucup
# 8   2018-08-01-008 Agatha Merih Trulin.G    Ucup
# 9   2018-08-01-009 Ahmad Fauji              Ucup
# 10  2018-08-01-010 Ahmad Fauzan             Ucup
# 11  2018-08-01-011 Ahmad Reyhan             Ucup
# 12  2018-08-01-012 Ahmad ridho              Ucup
# 13  2018-08-01-013 Aiya Diba                Ucup
# 14  2018-08-01-014 Ajra Bari Hanifah        Ucup
# 15  2018-08-01-015 Alam syah                Ucup
# 16  2018-08-01-016 Aldi Aulia Nugraha       Ucup
# 17  2018-08-01-017 Alisa Putri Mawadah      Ucup
# 18  2018-08-01-018 Alviandi                 Ucup
# ...
